# %% [markdown]
# <a href="https://colab.research.google.com/github/rltruter/Credit-Risk-Baseline/blob/main/Credit_Risk_Baseline_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

directory_path = '/content/drive/MyDrive/Credit Risk Baseline Data'

# Check if the directory exists
if os.path.exists(directory_path):
    files = os.listdir(directory_path)
    if files:
        print(f"Files in '{directory_path}':")
        for file_name in files:
            print(file_name)
    else:
        print(f"The directory '{directory_path}' is empty.")
else:
    print(f"The directory '{directory_path}' does not exist.")
# Out:
# Files in '/content/drive/MyDrive/Credit Risk Baseline Data':
# .ipynb_checkpoints
# LCDataDictionary.xlsx
# loan.csv

# %%
import pandas as pd
import os

directory_path = '/content/drive/MyDrive/Credit Risk Baseline Data'

# Define file paths for the second and third files
excel_file_path = os.path.join(directory_path, 'LCDataDictionary.xlsx')
csv_file_path = os.path.join(directory_path, 'loan.csv')

# Read the Excel file into a DataFrame
try:
    df_data_dictionary = pd.read_excel(excel_file_path)
    print(f"Successfully loaded '{os.path.basename(excel_file_path)}' into df_data_dictionary.")
    print("First 5 rows of df_data_dictionary:")
    display(df_data_dictionary.head())
except FileNotFoundError:
    print(f"Error: The file '{excel_file_path}' was not found.")
except Exception as e:
    print(f"Error loading Excel file: {e}")
# Out:
# Successfully loaded 'LCDataDictionary.xlsx' into df_data_dictionary.
# First 5 rows of df_data_dictionary:
#             LoanStatNew                                        Description
# 0        acc_now_delinq  The number of accounts on which the borrower i...
# 1  acc_open_past_24mths         Number of trades opened in past 24 months.
# 2            addr_state  The state provided by the borrower in the loan...
# 3              all_util              Balance to credit limit on all trades
# 4            annual_inc  The self-reported annual income provided by th...

# %%
# Read the CSV file into a DataFrame
try:
    df_loan_data = pd.read_csv(csv_file_path)
    print(f"\nSuccessfully loaded '{os.path.basename(csv_file_path)}' into df_loan_data.")
    print("First 5 rows of df_loan_data:")
    display(df_loan_data.head())
except FileNotFoundError:
    print(f"Error: The file '{csv_file_path}' was not found.")
except Exception as e:
    print(f"Error loading CSV file: {e}")
# Out:
# /tmp/ipython-input-1322949661.py:3: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_loan_data = pd.read_csv(csv_file_path)
# Successfully loaded 'loan.csv' into df_loan_data.
# First 5 rows of df_loan_data:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.56        84.92     C        C1  ...                            NaN
# 1     18.94       777.23     D        D2  ...                            NaN
# ...
